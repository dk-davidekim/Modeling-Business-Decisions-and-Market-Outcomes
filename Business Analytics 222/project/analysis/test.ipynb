# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('data/test.csv')
df
# Out:
#                                              StartDate  \
# 0                                           Start Date
# 1    {"ImportId":"startDate","timeZone":"America/De...
# 2                                  2023-04-15 13:21:28
# 3                                  2023-04-15 13:24:16
# 4                                  2023-04-15 13:24:08
# ..                                                 ...
# 104                                2023-04-23 13:35:07
# 105                                2023-04-23 13:34:41
# 106                                2023-04-23 13:35:03
# 107                                2023-04-23 13:34:09
# 108                                2023-04-23 14:00:08
#
#                                                EndDate                 Status  \
# 0                                             End Date          Response Type
# 1    {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
# ...

# %%
df.columns
# Out:
# Index(['StartDate', 'EndDate', 'Status', 'IPAddress', 'Progress',
#        'Duration (in seconds)', 'Finished', 'RecordedDate', 'ResponseId',
#        'RecipientLastName', 'RecipientFirstName', 'RecipientEmail',
#        'ExternalReference', 'LocationLatitude', 'LocationLongitude',
#        'DistributionChannel', 'UserLanguage', 'Q1', 'Q2', 'Q3', 'Q4', 'Q5_1',
#        'Q5_2', 'Q5_3', 'Q5_4', 'Q5_5', 'Q5_6', 'Q5_7', 'Q5_8', 'Q6', 'Q7_1',
#        'Q8', 'Q9_1', 'Q9_2', 'Q9_3', 'Q9_4', 'Q9_5', 'Q10', 'Q11', 'Q12',
#        'Q13', 'Q14_1', 'Q15'],
#       dtype='object')

# %%
df.IPAddress.nunique()
# Out:
# 59

# %%
df.IPAddress.unique()
# Out:
# array(['IP Address', '{"ImportId":"ipAddress"}', '174.196.202.163',
#        '107.77.225.125', '185.216.201.85', '128.197.29.237',
#        '71.233.191.13', '204.8.153.51', '128.197.29.255',
#        '128.197.29.232', '128.197.29.225', '174.168.180.88',
#        '128.197.29.249', '128.197.29.233', '71.232.45.56',
#        '128.197.29.230', '128.197.29.250', '128.197.29.234',
#        '128.197.29.240', '128.197.29.243', '128.197.29.251',
#        '104.28.39.129', '128.197.29.224', '107.77.223.76',
#        '128.197.29.239', '107.77.225.174', '174.242.64.120',
#        '107.77.223.106', '128.197.29.228', '128.197.29.235',
#        '128.197.29.247', '128.197.29.229', '107.115.17.88',
#        '128.197.29.226', '128.197.29.241', '166.198.21.80',
#        '172.56.193.104', '128.197.29.238', '128.197.29.231',
#        '128.197.29.245', '168.122.146.77', '172.58.221.61',
#        '128.197.29.236', '204.8.153.54', '128.197.29.244', '204.8.153.26',
# ...

# %%
df.IPAddress.value_counts()[df.IPAddress.value_counts().values > 1].__len__()
# Out:
# 27

# %%
df.loc[df.IPAddress.isin(df.IPAddress.value_counts()[df.IPAddress.value_counts().values > 1].index)]
# Out:
#                StartDate              EndDate      Status       IPAddress  \
# 5    2023-04-15 14:44:44  2023-04-15 14:46:59  IP Address  128.197.29.237
# 7    2023-04-15 20:17:09  2023-04-15 20:23:01  IP Address    204.8.153.51
# 8    2023-04-16 14:08:50  2023-04-16 14:12:47  IP Address  128.197.29.255
# 9    2023-04-16 14:13:23  2023-04-16 14:16:52  IP Address  128.197.29.232
# 10   2023-04-10 17:05:04  2023-04-10 17:05:18  IP Address  128.197.29.225
# ..                   ...                  ...         ...             ...
# 104  2023-04-23 13:35:07  2023-04-23 13:36:37  IP Address  128.197.29.224
# 105  2023-04-23 13:34:41  2023-04-23 13:36:56  IP Address  128.197.29.236
# 106  2023-04-23 13:35:03  2023-04-23 13:37:12  IP Address  128.197.29.238
# 107  2023-04-23 13:34:09  2023-04-23 13:37:58  IP Address  128.197.29.255
# 108  2023-04-23 14:00:08  2023-04-23 14:03:03  IP Address  128.197.29.228
#
#     Progress Duration (in seconds) Finished         RecordedDate  \
# ...

# %%
df.loc[df.IPAddress == '128.197.29.249']
# Out:
#                StartDate              EndDate      Status       IPAddress  \
# 12   2023-04-18 10:11:44  2023-04-18 10:16:21  IP Address  128.197.29.249
# 76   2023-04-20 20:09:55  2023-04-20 20:13:17  IP Address  128.197.29.249
# 95   2023-04-23 13:27:08  2023-04-23 13:31:06  IP Address  128.197.29.249
# 98   2023-04-23 13:30:00  2023-04-23 13:33:40  IP Address  128.197.29.249
# 102  2023-04-23 13:34:07  2023-04-23 13:36:09  IP Address  128.197.29.249
#
#     Progress Duration (in seconds) Finished         RecordedDate  \
# 12       100                   276     True  2023-04-18 10:16:21
# 76       100                   202     True  2023-04-20 20:13:18
# 95       100                   238     True  2023-04-23 13:31:06
# 98       100                   220     True  2023-04-23 13:33:41
# 102      100                   122     True  2023-04-23 13:36:10
#
#             ResponseId RecipientLastName  ... Q9_2 Q9_3 Q9_4 Q9_5  \
# ...

# %%
df.loc[df.IPAddress == '128.197.29.250']
# Out:
#               StartDate              EndDate      Status       IPAddress  \
# 16  2023-04-18 13:22:56  2023-04-18 13:25:56  IP Address  128.197.29.250
# 34  2023-04-19 13:29:25  2023-04-19 13:31:16  IP Address  128.197.29.250
# 43  2023-04-19 13:47:32  2023-04-19 13:50:50  IP Address  128.197.29.250
# 44  2023-04-19 13:49:05  2023-04-19 13:51:00  IP Address  128.197.29.250
# 47  2023-04-19 13:58:49  2023-04-19 14:02:43  IP Address  128.197.29.250
#
#    Progress Duration (in seconds) Finished         RecordedDate  \
# 16      100                   179     True  2023-04-18 13:25:56
# 34      100                   110     True  2023-04-19 13:31:16
# 43      100                   198     True  2023-04-19 13:50:51
# 44      100                   114     True  2023-04-19 13:51:01
# 47      100                   234     True  2023-04-19 14:02:44
#
#            ResponseId RecipientLastName  ... Q9_2 Q9_3 Q9_4 Q9_5  \
# 16  R_OpXa6OIphf8GiFX               NaN  ...    4    4    4    4
# ...

# %%
df.loc[df.IPAddress == '128.197.29.225']
# Out:
#                StartDate              EndDate      Status       IPAddress  \
# 10   2023-04-10 17:05:04  2023-04-10 17:05:18  IP Address  128.197.29.225
# 62   2023-04-19 15:28:32  2023-04-19 15:33:32  IP Address  128.197.29.225
# 92   2023-04-23 13:26:39  2023-04-23 13:28:59  IP Address  128.197.29.225
# 99   2023-04-23 13:30:01  2023-04-23 13:34:12  IP Address  128.197.29.225
# 103  2023-04-23 13:34:42  2023-04-23 13:36:29  IP Address  128.197.29.225
#
#     Progress Duration (in seconds) Finished         RecordedDate  \
# 10        27                    13    False  2023-04-17 17:05:22
# 62       100                   299     True  2023-04-19 15:33:32
# 92       100                   139     True  2023-04-23 13:28:59
# 99       100                   251     True  2023-04-23 13:34:13
# 103      100                   107     True  2023-04-23 13:36:30
#
#             ResponseId RecipientLastName  ... Q9_2 Q9_3 Q9_4 Q9_5  \
# ...

# %%
df.drop(columns = ['StartDate', 'EndDate', 'Status', 'IPAddress', 'Progress',
       'Duration (in seconds)', 'Finished', 'RecordedDate', 'RecipientLastName', 'RecipientFirstName', 'RecipientEmail',
       'ExternalReference', 'LocationLatitude', 'LocationLongitude',
       'DistributionChannel', 'UserLanguage'], inplace=True)

# %%
df.drop([1], inplace=True)

# %%
df
# Out:
#           ResponseId                    Q1                 Q2  \
# 0        Response ID  What is your gender?  What is your age?
# 2  R_ebTly6Krwl7vhol                     1                 22
#
#                                               Q3  \
# 0  What is your average annual household income?
# 2                                              4
#
#                                          Q4  \
# 0  How many times per week do you exercise?
# 2                                         3
#
#                                                 Q5_1  \
# 0  Other than water, which of the following drink...
# 2                                                  4
#
#                                                 Q5_2  \
# 0  Other than water, which of the following drink...
# 2                                                  4
#
#                                                 Q5_3  \
# 0  Other than water, which of the following drink...
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'Q1', 'Q2', 'Q3', 'Q4', 'Q5_1', 'Q5_2', 'Q5_3', 'Q5_4',
#        'Q5_5', 'Q5_6', 'Q5_7', 'Q5_8', 'Q6', 'Q7_1', 'Q8', 'Q9_1', 'Q9_2',
#        'Q9_3', 'Q9_4', 'Q9_5', 'Q10', 'Q11', 'Q12', 'Q13', 'Q14_1', 'Q15',
#        'Q15_3_TEXT'],
#       dtype='object')

# %%
['174.196.202.163',
       '107.77.225.125', '185.216.201.85', '128.197.29.237',
       '71.233.191.13', '204.8.153.51', '128.197.29.255',
       '128.197.29.232', '128.197.29.225', '174.168.180.88',
       '128.197.29.249', '128.197.29.233', '71.232.45.56',
       '128.197.29.230', '128.197.29.250', '128.197.29.234',
       '128.197.29.240', '128.197.29.243', '128.197.29.251',
       '104.28.39.129', '128.197.29.224', '107.77.223.76',
       '128.197.29.239', '107.77.225.174', '174.242.64.120',
       '107.77.223.106', '128.197.29.228', '128.197.29.235',
       '128.197.29.247', '128.197.29.229', '107.115.17.88',
       '128.197.29.226', '128.197.29.241', '166.198.21.80',
       '172.56.193.104', '128.197.29.238', '128.197.29.231',
       '128.197.29.245', '168.122.146.77', '172.58.221.61',
       '128.197.29.236', '204.8.153.54', '128.197.29.244', '204.8.153.26',
       '128.197.29.227', '128.197.29.254', '128.197.29.242',
       '107.77.225.73', '72.70.63.165', '172.58.223.221', '24.34.189.17',
       '24.34.168.242', '166.198.21.13', '76.19.216.15', '75.147.44.62',
       '172.56.193.40', '128.197.29.246'].__len__()
# Out:
# 57
